# %%
args={
    "image_dir":"mylut/printImg/print/color1mm_White1mm/mode1/slice",
}

image_files = sorted([f for f in os.listdir(args['image_dir']) if f.endswith('.png')])
